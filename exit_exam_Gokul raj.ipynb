# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv("Obesity.csv")

# %%
df
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
# ...

# %%
df.head()
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
# 3    Male  27.0    1.80    87.0                             no   no   3.0
# 4    Male  22.0    1.78    89.8                             no   no   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
# 3  3.0  Sometimes    no   2.0   no  2.0  0.0  Frequently
# 4  1.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
#
#                   MTRANS           NObeyesdad
# 0  Public_Transportation        Normal_Weight
# 1  Public_Transportation        Normal_Weight
# ...

# %%
df.tail()
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
#      FAVC  FCVC  NCP       CAEC SMOKE      CH2O SCC       FAF       TUE  \
# 2106  yes   3.0  3.0  Sometimes    no  1.728139  no  1.676269  0.906247
# 2107  yes   3.0  3.0  Sometimes    no  2.005130  no  1.341390  0.599270
# 2108  yes   3.0  3.0  Sometimes    no  2.054193  no  1.414209  0.646288
# 2109  yes   3.0  3.0  Sometimes    no  2.852339  no  1.139107  0.586035
# 2110  yes   3.0  3.0  Sometimes    no  2.863513  no  1.026452  0.714137
#
#            CALC                 MTRANS        NObeyesdad
# ...

# %% [markdown]
# ## Distrubution of NObeyesdad ##

# %%
    plt.hist(df['NObeyesdad'],bins=30, alpha=0.7, color='blue', edgecolor='black')
    plt.show()

# %%
df['NObeyesdad'].value_counts()
# Out:
# NObeyesdad
# Obesity_Type_I         351
# Obesity_Type_III       324
# Obesity_Type_II        297
# Overweight_Level_I     290
# Overweight_Level_II    290
# Normal_Weight          287
# Insufficient_Weight    272
# Name: count, dtype: int64

# %%
df.isna().sum()
# Out:
# Gender                             9
# Age                                0
# Height                            10
# Weight                             0
# family_history_with_overweight     6
# FAVC                               0
# FCVC                               0
# NCP                                0
# CAEC                               9
# SMOKE                              0
# CH2O                               0
# SCC                                7
# FAF                                0
# TUE                                0
# CALC                               0
# MTRANS                             7
# NObeyesdad                         0
# dtype: int64

# %% [markdown]
# # Plot distribution plots for numerical columns

# %%
# Plot distribution plots for numerical columns
for col in num_df:
  plt.figure(figsize=(8, 6))
  sns.distplot(num_df[col])
  plt.xlabel(col)
  plt.title(f'Distribution of {col}')
  plt.show()
# Out:
# C:\Users\gokul\AppData\Local\Temp\ipykernel_19356\3491346011.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(num_df[col])
# C:\Users\gokul\AppData\Local\Temp\ipykernel_19356\3491346011.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(num_df[col])
# ...

# %% [markdown]
# # Plot distribution plots for char columns

# %%
for i in char_df:
    plt.hist(char_df[i],bins=30, alpha=0.7, color='blue', edgecolor='black')
    plt.show()

# %% [markdown]
# # missing value treatment

# %%
 df['Height'].fillna(df['Height'].median(),inplace=True)
# Out:
# C:\Users\gokul\AppData\Local\Temp\ipykernel_19356\575439570.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Height'].fillna(df['Height'].median(),inplace=True)

# %%
df['Gender'].fillna(df['Gender'].mode()[0], inplace=True)

# %%
df['family_history_with_overweight'].fillna(df['family_history_with_overweight'].mode()[0], inplace=True)

# %%
df['CAEC'].fillna(df['CAEC'].mode()[0], inplace=True)

# %%
df['SCC'].fillna(df['SCC'].mode()[0], inplace=True)

# %%
df['MTRANS'].fillna(df['MTRANS'].mode()[0], inplace=True)

# %%
df.isna().sum()
# Out:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# NObeyesdad                        0
# dtype: int64

# %%
num_df = df.select_dtypes(include=['number'])
char_df = df.select_dtypes(include=['object'])

# %%
num_df
# Out:
#             Age    Height      Weight  FCVC  NCP      CH2O       FAF       TUE
# 0     21.000000  1.620000   64.000000   2.0  3.0  2.000000  0.000000  1.000000
# 1     21.000000  1.520000   56.000000   3.0  3.0  3.000000  3.000000  0.000000
# 2     23.000000  1.800000   77.000000   2.0  3.0  2.000000  2.000000  1.000000
# 3     27.000000  1.800000   87.000000   3.0  3.0  2.000000  2.000000  0.000000
# 4     22.000000  1.780000   89.800000   2.0  1.0  2.000000  0.000000  0.000000
# ...         ...       ...         ...   ...  ...       ...       ...       ...
# 2106  20.976842  1.710730  131.408528   3.0  3.0  1.728139  1.676269  0.906247
# 2107  21.982942  1.748584  133.742943   3.0  3.0  2.005130  1.341390  0.599270
# 2108  22.524036  1.752206  133.689352   3.0  3.0  2.054193  1.414209  0.646288
# 2109  24.361936  1.739450  133.346641   3.0  3.0  2.852339  1.139107  0.586035
# 2110  23.664709  1.738836  133.472641   3.0  3.0  2.863513  1.026452  0.714137
#
# [2111 rows x 8 columns]

# %%
char_df
# Out:
#       Gender family_history_with_overweight FAVC       CAEC SMOKE  SCC  \
# 0     Female                            yes   no  Sometimes    no   no
# 1     Female                            yes   no  Sometimes   yes  yes
# 2       Male                            yes   no  Sometimes    no   no
# 3       Male                             no   no  Sometimes    no   no
# 4       Male                             no   no  Sometimes    no   no
# ...      ...                            ...  ...        ...   ...  ...
# 2106  Female                            yes  yes  Sometimes    no   no
# 2107  Female                            yes  yes  Sometimes    no   no
# 2108  Female                            yes  yes  Sometimes    no   no
# 2109  Female                            yes  yes  Sometimes    no   no
# 2110  Female                            yes  yes  Sometimes    no   no
#
#             CALC                 MTRANS           NObeyesdad
# ...

# %% [markdown]
# # outlair treatment

# %%
import seaborn as sns

# %%
for i in num_df:
    sns.boxplot(num_df[i])
    plt.show()

# %%
for column in num_df:
    Q1 = num_df.quantile(0.25)
    Q3 = num_df.quantile(0.75)
    IQR = Q3 - Q1
    lb = Q1 - 1.5 * IQR
    ub = Q3 + 1.5 * IQR
    num_df = np.clip(num_df,lb, ub,axis=1)

# %%
for i in num_df:
    sns.boxplot(num_df[i])
    plt.show()

# %% [markdown]
# # scaling using minmax scaler

# %%
#scaling
from sklearn.preprocessing import MinMaxScaler
mm=MinMaxScaler()
scaler=mm.fit_transform(num_df)
df_scaled=pd.DataFrame(scaler,columns=num_df.columns)
df_scaled.head()
# Out:
#         Age    Height    Weight  FCVC       NCP  CH2O       FAF  TUE
# 0  0.195876  0.320755  0.186567   0.5  0.666667   0.5  0.000000  0.5
# 1  0.195876  0.132075  0.126866   1.0  0.666667   1.0  1.000000  0.0
# 2  0.216495  0.660377  0.283582   0.5  0.666667   0.5  0.666667  0.5
# 3  0.257732  0.660377  0.358209   1.0  0.666667   0.5  0.666667  0.0
# 4  0.206186  0.622642  0.379104   0.5  0.000000   0.5  0.000000  0.0

# %%
df_scaled
# Out:
#            Age    Height    Weight  FCVC       NCP      CH2O       FAF  \
# 0     0.195876  0.320755  0.186567   0.5  0.666667  0.500000  0.000000
# 1     0.195876  0.132075  0.126866   1.0  0.666667  1.000000  1.000000
# 2     0.216495  0.660377  0.283582   0.5  0.666667  0.500000  0.666667
# 3     0.257732  0.660377  0.358209   1.0  0.666667  0.500000  0.666667
# 4     0.206186  0.622642  0.379104   0.5  0.000000  0.500000  0.000000
# ...        ...       ...       ...   ...       ...       ...       ...
# 2106  0.195638  0.491943  0.689616   1.0  0.666667  0.364070  0.558756
# 2107  0.206010  0.563366  0.707037   1.0  0.666667  0.502565  0.447130
# 2108  0.211588  0.570200  0.706637   1.0  0.666667  0.527097  0.471403
# 2109  0.230535  0.546132  0.704079   1.0  0.666667  0.926170  0.379702
# 2110  0.223348  0.544974  0.705020   1.0  0.666667  0.931757  0.342151
#
#            TUE
# 0     0.500000
# 1     0.000000
# 2     0.500000
# 3     0.000000
# 4     0.000000
# ...        ...
# ...

# %% [markdown]
# # encoding using label encoder

# %%
#label labelencoder
from sklearn.preprocessing import LabelEncoder
for col in char_df:
    le=LabelEncoder()
    char_df[col] = le.fit_transform(char_df[col])

# %%
char_df
# Out:
#       Gender  family_history_with_overweight  FAVC  CAEC  SMOKE  SCC  CALC  \
# 0          0                               1     0     2      0    0     3
# 1          0                               1     0     2      1    1     2
# 2          1                               1     0     2      0    0     1
# 3          1                               0     0     2      0    0     1
# 4          1                               0     0     2      0    0     2
# ...      ...                             ...   ...   ...    ...  ...   ...
# 2106       0                               1     1     2      0    0     2
# 2107       0                               1     1     2      0    0     2
# 2108       0                               1     1     2      0    0     2
# 2109       0                               1     1     2      0    0     2
# 2110       0                               1     1     2      0    0     2
#
#       MTRANS  NObeyesdad
# 0          3           1
# ...

# %%
final_df = pd.concat([df_scaled, char_df], axis=1)

# %%
final_df
# Out:
#            Age    Height    Weight  FCVC       NCP      CH2O       FAF  \
# 0     0.195876  0.320755  0.186567   0.5  0.666667  0.500000  0.000000
# 1     0.195876  0.132075  0.126866   1.0  0.666667  1.000000  1.000000
# 2     0.216495  0.660377  0.283582   0.5  0.666667  0.500000  0.666667
# 3     0.257732  0.660377  0.358209   1.0  0.666667  0.500000  0.666667
# 4     0.206186  0.622642  0.379104   0.5  0.000000  0.500000  0.000000
# ...        ...       ...       ...   ...       ...       ...       ...
# 2106  0.195638  0.491943  0.689616   1.0  0.666667  0.364070  0.558756
# 2107  0.206010  0.563366  0.707037   1.0  0.666667  0.502565  0.447130
# 2108  0.211588  0.570200  0.706637   1.0  0.666667  0.527097  0.471403
# 2109  0.230535  0.546132  0.704079   1.0  0.666667  0.926170  0.379702
# 2110  0.223348  0.544974  0.705020   1.0  0.666667  0.931757  0.342151
#
#            TUE  Gender  family_history_with_overweight  FAVC  CAEC  SMOKE  \
# ...

# %% [markdown]
# # features selection

# %%
y = final_df["NObeyesdad"]
X = final_df.drop("NObeyesdad", axis=1)

# %%
y
# Out:
# 0       1
# 1       1
# 2       1
# 3       5
# 4       6
#        ..
# 2106    4
# 2107    4
# 2108    4
# 2109    4
# 2110    4
# Name: NObeyesdad, Length: 2111, dtype: int64

# %%
X
# Out:
#            Age    Height    Weight  FCVC       NCP      CH2O       FAF  \
# 0     0.195876  0.320755  0.186567   0.5  0.666667  0.500000  0.000000
# 1     0.195876  0.132075  0.126866   1.0  0.666667  1.000000  1.000000
# 2     0.216495  0.660377  0.283582   0.5  0.666667  0.500000  0.666667
# 3     0.257732  0.660377  0.358209   1.0  0.666667  0.500000  0.666667
# 4     0.206186  0.622642  0.379104   0.5  0.000000  0.500000  0.000000
# ...        ...       ...       ...   ...       ...       ...       ...
# 2106  0.195638  0.491943  0.689616   1.0  0.666667  0.364070  0.558756
# 2107  0.206010  0.563366  0.707037   1.0  0.666667  0.502565  0.447130
# 2108  0.211588  0.570200  0.706637   1.0  0.666667  0.527097  0.471403
# 2109  0.230535  0.546132  0.704079   1.0  0.666667  0.926170  0.379702
# 2110  0.223348  0.544974  0.705020   1.0  0.666667  0.931757  0.342151
#
#            TUE  Gender  family_history_with_overweight  FAVC  CAEC  SMOKE  \
# ...

# %% [markdown]
# # train test splitabs

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
X_train.shape, X_test.shape
# Out:
# ((1477, 16), (634, 16))

# %% [markdown]
# # prediction model bulding
#  # classification model¶

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_curve,auc,f1_score
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# # Logistic Regression

# %%
# Classification
# Logistic Regression
model_lr = LogisticRegression()
model_lr.fit(X_train, y_train)

y_predlr= model_lr.predict(X_test)

# Classification Report
print(classification_report(y_test,y_predlr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.88      0.80        86
#            1       0.73      0.44      0.55        93
#            2       0.69      0.70      0.69       102
#            3       0.79      0.98      0.87        88
#            4       0.92      0.99      0.95        98
#            5       0.64      0.59      0.62        88
#            6       0.53      0.49      0.51        79
#
#     accuracy                           0.73       634
#    macro avg       0.72      0.72      0.71       634
# weighted avg       0.72      0.73      0.72       634
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# ...

# %% [markdown]
# # RandomForest Classifier

# %%
# RandomForest Classifier
model_rf = RandomForestClassifier()
model_rf.fit(X_train, y_train)

y_pred_rf= model_rf.predict(X_test)

#Classification Report
print(classification_report(y_test,y_pred_rf))

#confusion matrix
conf_mat_rf = confusion_matrix(y_test,y_pred_rf)
plt.figure()
sns.heatmap(conf_mat_rf,annot=True,fmt='d')
plt.title("Confusion Matrix of Random Forest Classifier")
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.95      0.97        86
#            1       0.83      0.94      0.88        93
#            2       0.99      0.96      0.98       102
#            3       0.96      0.99      0.97        88
#            4       1.00      0.99      0.99        98
#            5       0.90      0.84      0.87        88
#            6       0.96      0.94      0.95        79
#
#     accuracy                           0.94       634
#    macro avg       0.95      0.94      0.94       634
# weighted avg       0.95      0.94      0.95       634

# %% [markdown]
# # Decision Tree

# %%
# Decision Tree
model_dt =DecisionTreeClassifier()
model_dt.fit(X_train,y_train)

y_pred_dt = model_dt.predict(X_test)

# Classification Report
print(classification_report(y_test,y_pred_dt))


# Confusion Matrix
conf_mat_dt = confusion_matrix(y_test,y_pred_dt)
plt.figure()
sns.heatmap(conf_mat_dt,annot=True,fmt='d')
plt.title("Confusion Matrix of Decision tree classifier")
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.91      0.91        86
#            1       0.79      0.86      0.82        93
#            2       0.96      0.91      0.93       102
#            3       0.96      0.98      0.97        88
#            4       1.00      0.99      0.99        98
#            5       0.87      0.78      0.83        88
#            6       0.87      0.94      0.90        79
#
#     accuracy                           0.91       634
#    macro avg       0.91      0.91      0.91       634
# weighted avg       0.91      0.91      0.91       634

# %% [markdown]
# # KNeighborsClassifier model

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_model = KNeighborsClassifier()
knn_model.fit(X_train, y_train)

y_pred_knn= knn_model.predict(X_test)

#Classification Report
print(classification_report(y_test,y_pred_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.90      0.79        86
#            1       0.70      0.51      0.59        93
#            2       0.77      0.77      0.77       102
#            3       0.80      0.95      0.87        88
#            4       0.96      0.99      0.97        98
#            5       0.74      0.61      0.67        88
#            6       0.71      0.70      0.70        79
#
#     accuracy                           0.78       634
#    macro avg       0.77      0.78      0.77       634
# weighted avg       0.77      0.78      0.77       634

# %%
from sklearn.svm import SVC
Svc_model = SVC()
Svc_model.fit(X_train, y_train)

y_pred_Svc= Svc_model.predict(X_test)

#Classification Report
print(classification_report(y_test,y_pred_Svc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.81      0.74        86
#            1       0.62      0.43      0.51        93
#            2       0.61      0.59      0.60       102
#            3       0.72      0.98      0.83        88
#            4       0.95      0.99      0.97        98
#            5       0.50      0.31      0.38        88
#            6       0.50      0.58      0.54        79
#
#     accuracy                           0.67       634
#    macro avg       0.65      0.67      0.65       634
# weighted avg       0.66      0.67      0.66       634
